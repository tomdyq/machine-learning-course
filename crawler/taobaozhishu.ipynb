# %%
res2 = rs.get('')

# %%
import requests
from bs4 import BeautifulSoup as bs
headers = {
    'cookie':'cna=DnntCmUAsBkCAUXMw1O1cEhW; miid=2859213138168461832; ali_ab=69.204.195.83.1391477325508.4; __utma=6906807.1361007871.1391477089.1394475139.1408582023.3; thw=cn; w=228c104f4a18f9152e3ba8df642679de; lzstat_uv=35937984781222672762|878758@3162875@2830612@862081@2945730@2948565@2798379@2043323@3045821@2801066@2208862@2341454@3201199@3499293@3492151@3349927@2285988@1744453; v=0; _tb_token_=stnMyUNkUBf3ue1; uc3=nk2=F5mVV%2F1gV6wA7b8%3D&id2=VypVqvQD06Y%3D&vt3=F8dASMlA7qpF9%2BcZU5g%3D&lg2=V32FPkk%2Fw0dUvg%3D%3D; existShop=MTQ0NDM1OTI1OA%3D%3D; lid=tomdyq_2006; lgc=tomdyq_2006; tracknick=tomdyq_2006; mt=np=; skt=4a4817fcfd3a5822; publishItemObj=Ng%3D%3D; _cc_=UtASsssmfA%3D%3D; tg=0; lc=Vy0XSrMXFwzIxNq97Wh%2FiA%3D%3D; cookie2=1c901e6b044ac9a8ee3fec3b25e94084; unb=46554355; t=b11c1cfb8a918e72a37181e2b5773a69; _umdata=32C8C7B30B9C45D1A04C4E0433984557C568F54DC2EC82D6B1520827EC347224AAD6A17031DA5AE272DAD8A57C858EE136382002C19010ACB49AD37164315A1EBD84D6BE76721A90; l=ApCQTV69MkGXrvgXOlHaTELr4NDij3Sj; isg=91577939AFEF9B96C558C08F947A1F91',
    'origin':'https://login.taobao.com',
    'referer':'https://login.taobao.com/?redirectURL=http%3A%2F%2Fshu.taobao.com%2Ftrendindex%3Fquery%3D%25E8%258C%25B6&style=mini&full_redirect=true',
    'upgrade-insecure-requests':'1',
    'user-agent':'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
    'content-type':'application/x-www-form-urlencoded'
}
rs = requests.session()

res = rs.get('https://login.taobao.com/member/login.jhtml?redirectURL=http%3A%2F%2Fshu.taobao.com%2Ftrendindex%3Fquery%3D%25E8%258C%25B6&ua=053UW5TcyMNYQwiAiwZTXFIdUh1SHJOe0BuOG4%3D%7CUm5OcktyS3VNeUZ9Qn9KcyU%3D%7CU2xMHDJ7G2AHYg8hAS8WLwEhD1MyVDhfIVt1I3U%3D%7CVGhXd1llXGVcYlpuUWpVaF1kU25MdkhwRHpHc011SHRNcE56RGo8%7CVWldfS0SMg8vEy8PIU8zVT5DIkUjDysOIHYg%7CVmNDbUMV%7CV2NDbUMV%7CWGRYeCgGZhtmH2VScVI2UT5fORtmD2gCawwuRSJHZFYtQCxNNlswTRNKDDxcIVwlDDMLNX5XaFBvIwo1DTJ%2BBGQYOkcuSSNKLQ9kA2ZPcEh3O0Y9UDZaO10xXC0EOwM9cQl1GGMTOgU9A01kW2NcZCseNwgwDzcCS2JdZVpiKhE7QTxMKEV1EHEXdlwyTipOGmEMYAF6F3wBMUw3SyYIKAYofig%3D%7CWWdHFyoKNxcpFyoKNQ83FysVLhU1DzQBIR0jGCMDOQYzZTM%3D%7CWmZYeCgGWjtdMVYoUn5EakpkOHs%2FEy8aOgcnGjoFOwQqfCo%3D%7CW2FBET9gO30pUDlDOUcgWzdjX3FRbU12QhRC%7CXGBdfVMDPwswCDISRWtXblNrVmJZZ1hgXWdcKRQ2DzoCOg41ADkHPwA0DTkGPWpEZFgOIHY%3D%7CXWVFFTt7L3cLYQRlGEA9VClIIw0tfUF5RWVZYF4IKBU1GzUVIRggdiA%3D%7CXmREFDplPngsVTxGPEIlXjJmWnRUaUl9RXoseg%3D%3D%7CX2VFFTt7L3cLYQRlGEA9VClIIw0tETEFPQlfCQ%3D%3D%7CQHlEeVlkRHtbZ15iQnxEfl5mUnJIcFBsUGlJdVVpUm9PcUVlUGREeEZmWGNDfUUT&TPL_username=tomdyq_2006&TPL_password=&TPL_checkcode=&loginsite=0&newlogin=0&TPL_redirect_url=http%3A%2F%2Fshu.taobao.com%2Ftrendindex%3Fquery%3D%25E8%258C%25B6&from=tb&fc=default&style=mini&css_style=&tid=&support=000001&CtrlVersion=1%2C0%2C0%2C7&loginType=3&minititle=&minipara=&umto=NaN&pstrong=&sign=&need_sign=&isIgnore=&full_redirect=true&popid=&callback=&guf=&not_duplite_str=&need_user_id=&poy=&gvfdcname=&gvfdcre=687474703A2F2F7368752E74616F62616F2E636F6D2F&from_encoding=&sub=&TPL_password_2=&loginASR=1&loginASRSuc=1&allp=&oslanguage=en-US&sr=1366*768&osVer=windows%7C6.1&naviVer=chrome%7C44.02403157', headers = headers)
print res.text
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="gbk" />
# <meta http-equiv="X-UA-Compatible" content="IE=edge" >
# <meta name="description" content="淘宝网(Taobao.com)作为专业的购物网站拥有全球时尚前沿的消费者购物集市,100%认证网上商城及超值二手商品区，同时购物安全，产品丰富，应有尽有,任你选购,让你尽享网上在线购物乐趣！" />
# <meta name="keywords" content="淘宝,掏宝,网上购物,C2C,在线交易,交易市场,网上交易,交易市场,网上买,网上卖，购物网站,团购,网上贸易,安全购物,电子商务,放心买,供应,买卖信息,网店,一口价,拍卖,网上开店,网络购物,打折,免费开店,网购,频道,店铺" />
#
#
# <link rel="search" type="application/opensearchdescription+xml" href="http://assets.taobaocdn.com/plugins/opensearch/provider.xml" title="淘宝购物" />
# <script>window._lgst_ = new Date().getTime();</script>
# <link rel="stylesheet" href="https://assets.alicdn.com/g/tb/login/0.3.8/css/mini.css?t=20130321" />
# <script type="text/javascript">
#    var tbdw_frame_count = true;
# </script>
# <script src="https://assets.alicdn.com/g/kissy/k/1.4.4/seed-min.js"></script>
# <link rel="shortcut icon" href="https://assets.alicdn.com/apps/login/static/img/favicon.ico" type="image/x-icon" />
#
# ...

# %%
res2 = rs.get('http://shu.taobao.com/trendindex?query=%E8%8C%B6', headers = headers)
print res2.text
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta name="data-spm" content="a2107" />
# <title>淘宝网 - 淘！我喜欢</title>
# <meta charset="gbk" />
# <meta http-equiv="X-UA-Compatible" content="IE=8" />
# <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1"/>
# <meta name="description" content="淘宝网(Taobao.com)作为专业的购物网站拥有全球时尚前沿的消费者购物集市,100%认证网上商城及超值二手商品区，同时购物安全，产品丰富，应有尽有,任你选购,让你尽享网上在线购物乐趣！" />
# <meta name="keywords" content="淘宝,掏宝,网上购物,C2C,在线交易,交易市场,网上交易,交易市场,网上买,网上卖，购物网站,团购,网上贸易,安全购物,电子商务,放心买,供应,买卖信息,网店,一口价,拍卖,网上开店,网络购物,打折,免费开店,网购,频道,店铺" />
# <script>window._lgst_ = new Date().getTime();</script>
# <script>
# //全登陆不允许iframe嵌入
# if(window.top !== window.self){ window.top.location = window.location;}
# </script>
# <link rel="shortcut icon" href="https://assets.alicdn.com/apps/login/static/img/favicon.ico" type="image/x-icon" />
# <link rel="stylesheet" href="https://assets.alicdn.com/g/tb/login/0.3.8/css/new-login.css?t=20150420"/>
# ...

# %% [markdown]
# # 线性回归 Linear Regression
# * 找出两个变数之间的线性关系
# * 极小化 Mean square error
# <img src='fig/regression.gif'>

# %% [markdown]
# ### 然后，可以干嘛？
# * 来看个范例：
#     * 安信证券：基于有效因子的多因子选股模型

# %% [markdown]
# # 注意事项：在用之前要先安装numexpr
# * pip install numexpr

# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pylab as plt
import seaborn as sns

# %%
df_all = pd.read_csv('data/factor_grps.csv')
df = df_all.query('factor_hash=="factor0"')
df
# Out:
#   factor_hash  stock_group  sharpe_ratio
# 0     factor0            1         0.398
# 1     factor0            2         0.332
# 2     factor0            3         0.406
# 3     factor0            4         0.399
# 4     factor0            5         0.440
# 5     factor0            6         0.388
# 6     factor0            7         0.329
# 7     factor0            8         0.345
# 8     factor0            9         0.202
# 9     factor0           10         0.211

# %%
pd.ols(y=df.sharpe_ratio, x=df.stock_group)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-9ae23e93428f> in <module>()
# ----> 1 pd.ols(y=df.sharpe_ratio, x=df.stock_group)
#
# /usr/local/lib/python2.7/dist-packages/pandas/stats/interface.pyc in ols(**kwargs)
#     141             klass = MovingOLS
#     142
# --> 143     return klass(**kwargs)
#
# /usr/local/lib/python2.7/dist-packages/pandas/stats/ols.pyc in __init__(self, y, x, intercept, weights, nw_lags, nw_overlap)
#      51             import statsmodels.api as sm
#      52         except ImportError:
# ---> 53             import scikits.statsmodels.api as sm
#      54
#      55         self._x_orig = x
#
# ImportError: No module named scikits.statsmodels.api

# %%
sns.lmplot("stock_group", "sharpe_ratio", df)

# %%
def get_factor_regression_line(df, factor_id):
    factor = 'factor'+str(factor_id)
    df = df_all.query('factor_hash=="%s"'%factor)
    sns.lmplot("stock_group", "sharpe_ratio", df)

# %%
for i in range(10):
    get_factor_regression_line(df_all, i)
